# %% [markdown]
# <a href="https://colab.research.google.com/github/pns37/BTE320/blob/main/bte320ENotes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello")
# Out:
# Hello

# %% [markdown]
# This is a test
